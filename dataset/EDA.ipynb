# %%
import pandas as pd

# %% [markdown]
# ## Data cleaning

# %%
df=pd.read_csv("adult.csv")

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  country         32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'country', 'salary'],
#       dtype='object')

# %%
df["age"].isnull().sum()
# Out:
# 0

# %%
df["workclass"].isnull().sum()
# Out:
# 0

# %%
df.duplicated().sum()

# by this command we are able to understand the duplicate data is present that is 24
# Out:
# 24

# %%
df[df.duplicated()]
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# 18555   30            Private  144593        HS-grad              9
# 18698   19            Private   97261        HS-grad              9
# 21318   19            Private  138153   Some-college             10
# 21490   19            Private  146679   Some-college             10
# 21875   49            Private   31267        7th-8th              4
# 22300   25            Private  195994        1st-4th              2
# ...

# %%
df.drop_duplicates(df[df.duplicated()],keep="first",inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, country, salary]
# Index: []

# %%
df.duplicated().sum()

# here we can say that there is not any duplicated value
# Out:
# 0

# %%
df[df["fnlwgt"]==308144]

# this is the way how can we confirmed that this is duplicated value
# Out:
#       age workclass  fnlwgt   education  education-num  marital-status  \
# 4325   25   Private  308144   Bachelors             13   Never-married
#
#          occupation    relationship    race    sex  capital-gain  \
# 4325   Craft-repair   Not-in-family   White   Male             0
#
#       capital-loss  hours-per-week  country  salary
# 4325             0              40   Mexico   <=50K

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'country', 'salary'],
#       dtype='object')

# %%
# here is some problem in data
df["workclass"].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df["workclass"].value_counts()
# Out:
# workclass
#  Private             22673
#  Self-emp-not-inc     2540
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: count, dtype: int64

# %%
from statistics import mode

df["workclass"].mode()

# mode of this categorical data is "private" its mean that most of people are worked at private service
# Out:
# 0     Private
# Name: workclass, dtype: object

# %%
df["workclass"]=df["workclass"].str.replace(' ?',' Private')

# %%
df["workclass"].unique()

# here we get all mention data values
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' Self-emp-inc', ' Without-pay', ' Never-worked'],
#       dtype=object)

# %%
# this is fine.

df["education"].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
df["marital-status"].unique()
# Out:
# array([' Never-married', ' Married-civ-spouse', ' Divorced',
#        ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#        ' Widowed'], dtype=object)

# %%
df["occupation"].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df["occupation"].value_counts()

# here most of people's occupation is  "Prof-specialty"
# Out:
# occupation
#  Prof-specialty       4136
#  Craft-repair         4094
#  Exec-managerial      4065
#  Adm-clerical         3768
#  Sales                3650
#  Other-service        3291
#  Machine-op-inspct    2000
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1369
#  Farming-fishing       992
#  Tech-support          927
#  Protective-serv       649
#  Priv-house-serv       147
#  Armed-Forces            9
# Name: count, dtype: int64

# %%
df["occupation"]=df["occupation"].str.replace(' ?',' Prof-specialty')

# %%
df["occupation"].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df["relationship"].unique()
# Out:
# array([' Not-in-family', ' Husband', ' Wife', ' Own-child', ' Unmarried',
#        ' Other-relative'], dtype=object)

# %%
df["race"].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
df["sex"].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
## there is one country are not mantioning

df["country"].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
df["salary"].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
## numerical 
df["age"].isnull().sum()
# Out:
# 0

# %%
df["age"].unique()
# Out:
# array([39, 50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43,
#        54, 35, 59, 56, 19, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#        46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#        26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78, 88, 82,
#        83, 84, 85, 86, 87], dtype=int64)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'country', 'salary'],
#       dtype='object')

# %%
df.sample()
# Out:
#       age workclass  fnlwgt      education  education-num  marital-status  \
# 6836   23   Private   70261   Some-college             10   Never-married
#
#           occupation relationship    race    sex  capital-gain  capital-loss  \
# 6836   Other-service    Own-child   White   Male             0             0
#
#       hours-per-week         country  salary
# 6836              30   United-States   <=50K

# %%
df["fnlwgt"].isnull().sum()
# Out:
# 0

# %%
df["fnlwgt"].unique()
# Out:
# array([ 77516,  83311, 215646, ...,  34066,  84661, 257302], dtype=int64)

# %%
df["education-num"].isnull().sum()
# Out:
# 0

# %%
df["education-num"].unique()
# Out:
# array([13,  9,  7, 14,  5, 10, 12, 11,  4, 16, 15,  3,  6,  2,  1,  8],
#       dtype=int64)

# %%
df["capital-gain"].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32537 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32537 non-null  int64
#  1   workclass       32537 non-null  object
#  2   fnlwgt          32537 non-null  int64
#  3   education       32537 non-null  object
#  4   education-num   32537 non-null  int64
#  5   marital-status  32537 non-null  object
#  6   occupation      32537 non-null  object
#  7   relationship    32537 non-null  object
#  8   race            32537 non-null  object
#  9   sex             32537 non-null  object
#  10  capital-gain    32537 non-null  int64
#  11  capital-loss    32537 non-null  int64
#  12  hours-per-week  32537 non-null  int64
#  13  country         32537 non-null  object
#  14  salary          32537 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 4.0+ MB

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'country', 'salary'],
#       dtype='object')

# %%
df.rename(columns={'education-num':'education_num','capital-gain':'capital_gain', 'capital-loss':'capital_loss', 'hours-per-week':'hours_per_week'},inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'country', 'salary'],
#       dtype='object')

# %%
#this  syntax use for --make another data copy of cleaned data
df.to_csv("cleaned_adult.csv",index=False)

# %% [markdown]
# ## now we need to do some  statistical analysis

# %%
numerical_col=[feature for feature in df.columns if df[feature].dtype !="O"]
numerical_col
# Out:
# ['age',
#  'fnlwgt',
#  'education_num',
#  'capital_gain',
#  'capital_loss',
#  'hours_per_week']

# %%
categorical_col=[feature for feature in df.columns if df[feature].dtype =="O"]
categorical_col
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'country',
#  'salary']

# %%
# by this syntax we can find that how much percentage people are there.

for col in categorical_col:
    print(f"{col}:{df[col].value_counts(normalize=True)*100}")
    print("============================")
# Out:
# workclass:workclass
#  Private             75.326551
#  Self-emp-not-inc     7.806497
#  Local-gov            6.432677
#  State-gov            3.989304
#  Self-emp-inc         3.429941
#  Federal-gov          2.950487
#  Without-pay          0.043028
#  Never-worked         0.021514
# Name: proportion, dtype: float64
# ...
# education:education
#  HS-grad         32.252513
#  Some-college    22.380674
#  Bachelors       16.452039
#  Masters          5.292436
#  Assoc-voc        4.247472
#  11th             3.611273
#  Assoc-acdm       3.279344
#  10th             2.867505
#  7th-8th          1.982359
#  Prof-school      1.770292
#  9th              1.579740
#  12th             1.330793
#  Doctorate        1.269324
#  5th-6th          1.020377
#  1st-4th          0.510188
#  Preschool        0.153671
# Name: proportion, dtype: float64
# ...
# marital-status:marital-status
#  Married-civ-spouse       46.009159
#  Never-married            32.784215
#  Divorced                 13.649076
# ...

# %%
df['marital-status'].value_counts(normalize=True)*100
# Out:
# marital-status
#  Married-civ-spouse       46.009159
#  Never-married            32.784215
#  Divorced                 13.649076
#  Separated                 3.150260
#  Widowed                   3.051910
#  Married-spouse-absent     1.284691
#  Married-AF-spouse         0.070689
# Name: proportion, dtype: float64

# %%
df['occupation'].value_counts(normalize=True)*100
# Out:
# occupation
#  Prof-specialty       18.376003
#  Craft-repair         12.582598
#  Exec-managerial      12.493469
#  Adm-clerical         11.580662
#  Sales                11.217998
#  Other-service        10.114639
#  Machine-op-inspct     6.146848
#  Transport-moving      4.908258
#  Handlers-cleaners     4.207518
#  Farming-fishing       3.048837
#  Tech-support          2.849064
#  Protective-serv       1.994652
#  Priv-house-serv       0.451793
#  Armed-Forces          0.027661
# Name: proportion, dtype: float64

# %%
## we also fine this things by graph
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,15))
plt.suptitle("Univariate analysis of the categorical feature",fontsize=20,fontweight="bold",alpha=0.8,y=1.)
category=['marital-status','relationship']
for i in range(0,len(category)):
    plt.subplot(2,2,i+1)
    sns.countplot(x=df[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
numerical_col
# Out:
# ['age',
#  'fnlwgt',
#  'education_num',
#  'capital_gain',
#  'capital_loss',
#  'hours_per_week']

# %%
sns.kdeplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(df['hours-per-week'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\windows(E)\Adult_census_projet\venv\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\windows(E)\Adult_census_projet\venv\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\windows(E)\Adult_census_projet\venv\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hours-per-week'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
## univariate analysis for the numerical columns
import warnings
warnings.filterwarnings("ignore")


plt.figure(figsize=(20,30))
plt.suptitle("Univariate analysis of numberical columns",fontsize=20,fontweight="bold",alpha=0.8,y=1.)

for i in range(0,len(numerical_col)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=df[numerical_col[i]],shade=True,color="b")
    plt.xlabel(numerical_col[i])
    plt.tight_layout()

plt.figure(figsize=(20,30))
plt.suptitle("Univariate analysis of numberical columns",fontsize=20,fontweight="bold",alpha=0.8,y=1.)

for i in range(0,len(numerical_col)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=df[numerical_col[i]],shade=True,color="b")
    plt.xlabel(numerical_col[i])
    plt.tight_layout()

# %%
df['education'].value_counts().plot.pie(y=df['education'],figsize=(20,15),autopct="%1.1f%%")

# by this we can say that hs-grad people has most census count that is 32.3%
# Out:
# <Axes: ylabel='count'>

# %%
# which education have most education number?

# %%
df.sample(2)
# Out:
#        age workclass  fnlwgt education  education-num       marital-status  \
# 26006   27   Private  175821   HS-grad              9   Married-civ-spouse
# 4463    49   Private  197418   HS-grad              9              Widowed
#
#           occupation relationship    race      sex  capital-gain  \
# 26006   Adm-clerical         Wife   White   Female             0
# 4463    Adm-clerical    Unmarried   White   Female             0
#
#        capital-loss  hours-per-week         country  salary
# 26006             0              34   United-States   <=50K
# 4463              0              20   United-States   <=50K

# %%
df.groupby(['education'])['education-num'].sum().sort_values(ascending=False)
# Out:
# education
#  HS-grad         94446
#  Some-college    72820
#  Bachelors       69589
#  Masters         24108
#  Assoc-voc       15202
#  Assoc-acdm      12804
#  Prof-school      8640
#  11th             8225
#  Doctorate        6608
#  10th             5598
#  12th             3464
#  7th-8th          2580
#  9th              2570
#  5th-6th           996
#  1st-4th           332
#  Preschool          50
# Name: education-num, dtype: int64

# %%
df.groupby(['education'])['hours-per-week'].sum()
# Out:
# education
#  10th             34570
#  11th             39863
#  12th             15493
#  1st-4th           6347
#  5th-6th          12898
#  7th-8th          25391
#  9th              19555
#  Assoc-acdm       43218
#  Assoc-voc        57506
#  Bachelors       228113
#  Doctorate        19400
#  HS-grad         425794
#  Masters          75480
#  Preschool         1819
#  Prof-school      27317
#  Some-college    283043
# Name: hours-per-week, dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
df.sample(2)
# Out:
#        age workclass  fnlwgt education  education-num       marital-status  \
# 25021   17   Private  122041      11th              7        Never-married
# 30487   61   Private  142922   HS-grad              9   Married-civ-spouse
#
#               occupation relationship    race    sex  capital-gain  \
# 25021       Craft-repair    Own-child   White   Male             0
# 30487   Transport-moving      Husband   White   Male             0
#
#        capital-loss  hours-per-week         country  salary
# 25021             0              20   United-States   <=50K
# 30487             0              40   United-States   <=50K

# %%
categorical_col
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'country',
#  'salary']

# %%
df["workclass"].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' Self-emp-inc', ' Without-pay', ' Never-worked'],
#       dtype=object)

# %%
df['education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
df['marital-status'].unique()
# Out:
# array([' Never-married', ' Married-civ-spouse', ' Divorced',
#        ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#        ' Widowed'], dtype=object)

# %%
df['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df['relationship'].unique()
# Out:
# array([' Not-in-family', ' Husband', ' Wife', ' Own-child', ' Unmarried',
#        ' Other-relative'], dtype=object)

# %%
df['race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
df['country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
df["salary"].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
# hare we take LabelEncoder beacuse we can not say which is better that this or that

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
column = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'country', 'salary']
for col in column:
    df[col] = le.fit_transform(df[col])

# here we do with the label encoder but we cannot use for train data therefore we use onehotencoding for modular coding

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       39          6   77516          9             13               4
# 1       50          5   83311          9             13               2
# 2       38          3  215646         11              9               0
# 3       53          3  234721          1              7               2
# 4       28          3  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          3  257302          7             12               2
# 32557   40          3  154374         11              9               2
# 32558   58          3  151910         11              9               6
# 32559   22          3  201490         11              9               4
# 32560   52          4  287927         11              9               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
df.corr()
# Out:
#                      age  workclass    fnlwgt  education  education-num  \
# age             1.000000   0.040461 -0.076447  -0.010551       0.036224
# workclass       0.040461   1.000000 -0.024272   0.004824       0.003503
# fnlwgt         -0.076447  -0.024272  1.000000  -0.028053      -0.043388
# education      -0.010551   0.004824 -0.028053   1.000000       0.359085
# education-num   0.036224   0.003503 -0.043388   0.359085       1.000000
# marital-status -0.266137  -0.020430  0.028123  -0.038422      -0.069161
# occupation      0.001755   0.007159 -0.000023  -0.041240       0.070907
# relationship   -0.263744  -0.057920  0.008868  -0.011057      -0.094432
# race            0.029116   0.048349 -0.021497   0.014303       0.032011
# sex             0.088708   0.071570  0.027089  -0.027433       0.012205
# capital-gain    0.077676   0.031506  0.000429   0.030085       0.122664
# capital-loss    0.057745   0.002643 -0.010260   0.016793       0.079892
# ...

# %%
sns.heatmap(df.corr(),annot=True,annot_kws={'size': 6})
plt.suptitle("this is the correlation between the data",fontsize=.5,fontweight="bold",alpha=0.8)
plt.figure(figsize=(20,45))
plt.show()

# %% [markdown]
# ###### based on upper graph and correlation  we can say that ,In this (fnlwgt,marital-status,country,relationship ) .they will not much effect the salary that's why we can drop them

# %%
df.drop(labels=["fnlwgt","marital-status","country","relationship"],axis=1,inplace=True)

# %%
df
# Out:
#        age  workclass  education  education-num  occupation  race  sex  \
# 0       39          6          9             13           0     4    1
# 1       50          5          9             13           3     4    1
# 2       38          3         11              9           5     4    1
# 3       53          3          1              7           5     2    1
# 4       28          3          9             13           9     2    0
# ...    ...        ...        ...            ...         ...   ...  ...
# 32556   27          3          7             12          12     4    0
# 32557   40          3         11              9           6     4    1
# 32558   58          3         11              9           0     4    0
# 32559   22          3         11              9           0     4    1
# 32560   52          4         11              9           3     4    0
#
#        capital-gain  capital-loss  hours-per-week  salary
# ...

# %%
df.to_csv("Numerical_converted_adult.csv",index=False)
